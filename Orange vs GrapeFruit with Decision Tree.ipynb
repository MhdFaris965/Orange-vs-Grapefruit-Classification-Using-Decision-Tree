# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('citrus.csv')

# %%
df
# Out:
#             name  diameter  weight  red  green  blue
# 0         orange      2.96   86.76  172     85     2
# 1         orange      3.91   88.05  166     78     3
# 2         orange      4.42   95.17  156     81     2
# 3         orange      4.47   95.60  163     81     4
# 4         orange      4.48   95.76  161     72     9
# ...          ...       ...     ...  ...    ...   ...
# 9995  grapefruit     15.35  253.89  149     77    20
# 9996  grapefruit     15.41  254.67  148     68     7
# 9997  grapefruit     15.59  256.50  168     82    20
# 9998  grapefruit     15.92  260.14  142     72    11
# 9999  grapefruit     16.45  261.51  152     74     2
#
# [10000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10000 non-null  object
#  1   diameter  10000 non-null  float64
#  2   weight    10000 non-null  float64
#  3   red       10000 non-null  int64
#  4   green     10000 non-null  int64
#  5   blue      10000 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#            diameter        weight           red         green          blue
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       9.975685    175.050792    153.847800     76.010600     11.363200
# std        1.947844     29.212119     10.432954     11.708433      9.061275
# min        2.960000     86.760000    115.000000     31.000000      2.000000
# 25%        8.460000    152.220000    147.000000     68.000000      2.000000
# 50%        9.980000    174.985000    154.000000     76.000000     10.000000
# 75%       11.480000    197.722500    161.000000     84.000000     17.000000
# max       16.450000    261.510000    192.000000    116.000000     56.000000

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['name']=le.fit_transform(df['name'])

# %%
import Faris_Stats as fs 
for i in df.columns:
    print(i)
    fs.cal_pr(df[i])
# Out:
# name
# Total Revenue 5000
# Total_count 10000
# Mean 0.5
# median 0.5
# minimum 0
# Maximum 1
# range 1
# variance 0.25
# Standard deviation 0.5
# Quartile 1 : 0.0
# quartile 3 : 1.0
# inter quartile range 1.0
# lower_whisker -1.5
# upper_whisker 2.5
# Skewness 0.0
# kurtosis -2.0
# diameter
# Total Revenue 99756.85
# Total_count 10000
# Mean 9.975685
# median 9.98
# minimum 2.96
# Maximum 16.45
# range 13.489999999999998
# variance 3.7937155107750296
# Standard deviation 1.9477462644746697
# Quartile 1 : 8.46
# quartile 3 : 11.48
# inter quartile range 3.0199999999999996
# lower_whisker 3.9300000000000015
# upper_whisker 16.009999999999998
# Skewness -0.028313016667624907
# kurtosis -0.6681866401135328
# weight
# Total Revenue 1750507.92
# Total_count 10000
# Mean 175.050792
# median 174.985
# minimum 86.76
# Maximum 261.51
# range 174.75
# variance 853.262576972732
# Standard deviation 29.210658619290527
# Quartile 1 : 152.22
# quartile 3 : 197.7225
# inter quartile range 45.5025
# ...

# %%
sns.countplot(data=df,x='name')
plt.show()

# %%
for i in df.drop('name',axis=1).columns:
    print(i)
    sns.displot(df[i])
    plt.show()
# Out:
# diameter
# weight
# red
# green
# blue

# %%
for i in df.columns:
    print (i)
    sns.kdeplot(df[i])
    plt.show()
# Out:
# name
# diameter
# weight
# red
# green
# blue

# %%
sns.pairplot(df,hue='name' )
plt.show()

# %%
for i in df.columns:
    print (i)
    sns.boxplot(df[i])
    plt.show()
# Out:
# name
# diameter
# weight
# red
# green
# blue

# %%
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
# Out:
# <Axes: >

# %%
X=df.drop('name',axis=1)
y=df['name']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %%
len(X)
# Out:
# 10000

# %%
#sample training were will know the input and output
len(X_train)
# Out:
# 7500

# %%
#outside sample only know the input
len(X_test)
# Out:
# 2500

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_train = dtc.predict(X_train)
y_pred_test = dtc.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3738
#            1       1.00      1.00      1.00      3762
#
#     accuracy                           1.00      7500
#    macro avg       1.00      1.00      1.00      7500
# weighted avg       1.00      1.00      1.00      7500

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      1262
#            1       0.95      0.94      0.95      1238
#
#     accuracy                           0.95      2500
#    macro avg       0.95      0.95      0.95      2500
# weighted avg       0.95      0.95      0.95      2500

# %%
#USUALLY DECISION TREES ARE OVERFIT

# %%
diameter = int(input('please enter the diameter here :'))
weight = int(input('please enter the weight here'))
red = int(input('please enter the red value here'))
green= int(input('enter the green value here'))
blue= int(input('please enter the blue value here'))

user_input=np.array([diameter,weight,red,green,blue]).reshape(1,-1)
if dtc.predict(user_input)==0:
    print('GRAPEFRUIT')
else:
    print('ORANGE')
# Out:
# GRAPEFRUIT
# c:\Users\muham\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(10,8))
plot_tree(dtc)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
hyper_para_dic = {'criterion':['gini','entropy'],
                  'max_depth':[2,4,6,8,10],
                  'min_samples_split':[2,3,5,7,9],
                  'min_samples_leaf':[2,4,5,8,9],
                  'max_features':['sqrt','log2']
                  }

# %%
grid_model=GridSearchCV(estimator=dtc,param_grid=hyper_para_dic,cv=5)

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [2, 4, 5, 8, 9],
#                          'min_samples_split': [2, 3, 5, 7, 9]})

# %%
grid_model.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'max_features': 'log2',
#  'min_samples_leaf': 4,
#  'min_samples_split': 3}

# %%
best_dtc = grid_model.best_estimator_

# %%
y_pred_train = best_dtc.predict(X_train)
y_pred_test = best_dtc.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95      3738
#            1       0.95      0.96      0.95      3762
#
#     accuracy                           0.95      7500
#    macro avg       0.95      0.95      0.95      7500
# weighted avg       0.95      0.95      0.95      7500

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      1262
#            1       0.91      0.91      0.91      1238
#
#     accuracy                           0.91      2500
#    macro avg       0.91      0.91      0.91      2500
# weighted avg       0.91      0.91      0.91      2500

# %% [markdown]
# RandomForestCV

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
hyper_para_dic = {'n_estimators':[50,100,200],
                  'criterion':['gini','entropy'],
                  'max_depth':[2,4,6,8,10],
                  'min_samples_split':[2,3,5,7,9],
                  'min_samples_leaf':[2,4,5,8,9],
                  'max_features':['sqrt','log2']
                  }

# %%
grid_model=GridSearchCV(estimator=rfc,param_grid=hyper_para_dic,cv=5)

# %%
grid_model.fit(X_train,y_train)

# %%
y_pred_train = best_rfc.predict(X_train)
y_pred_test = best_rfc.predict(X_test)

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      3748
#            1       0.95      0.95      0.95      3752
#
#     accuracy                           0.95      7500
#    macro avg       0.95      0.95      0.95      7500
# weighted avg       0.95      0.95      0.95      7500

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      3748
#            1       0.95      0.95      0.95      3752
#
#     accuracy                           0.95      7500
#    macro avg       0.95      0.95      0.95      7500
# weighted avg       0.95      0.95      0.95      7500
